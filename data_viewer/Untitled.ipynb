# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import colors

np.random.seed(50)
df = pd.DataFrame({'A':
                   [-2,-3,-1,-74,-21,-33,-5,-177,-20,-513,-15,-398,-15,-328,-5,-90,534,3182,7110,9458,5057,7675,4450,9320,8174,9061,2277,7763,874,13437,336,2396,192,911,25,6851]
                  })
# df = pd.concat([df, pd.DataFrame(np.random.randn(20, 4)*20, columns=list('ABCD'))],
#                axis=1)
# df.iloc[0, 2] = 0.0
cm = sns.color_palette("RdYlGn", as_cmap=True)

def background_gradient(s, m, M, cmap='PuBu', low=0, high=0):
    rng = M - m
    norm = colors.Normalize(m - (rng * low),
                            M + (rng * high))
    normed = norm(s.values)
    c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
    print(c)
    return ['background-color: %s' % color for color in c]

even_range = np.max([np.abs(df.values.min()), np.abs(df.values.max())])
df.style.apply(background_gradient,
               cmap=cm,
               m=-even_range,
               M=even_range).set_precision(2)
# Out:
# ['#fffebe', '#fffebe', '#fffebe', '#fffebe', '#fffebe', '#fffebe', '#fffebe', '#fffdbc', '#fffebe', '#fffab6', '#fffebe', '#fffbb8', '#fffebe', '#fffbb8', '#fffebe', '#fffebe', '#f7fcb4', '#cfeb85', '#7dc765', '#3ca959', '#abdb6d', '#6ec064', '#b7e075', '#42ac5a', '#63bc62', '#48ae5c', '#dff293', '#6ec064', '#f2faae', '#006837', '#fafdb8', '#ddf191', '#fdfebc', '#f2faae', '#feffbe', '#82c966']
# <style  type="text/css" >
# ...
